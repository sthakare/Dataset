# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('gapminder.tsv',sep='\t')

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.331999999999997, 9240934,
#         820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.1007099999999],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499602999999],
#        ['Zimbabwe', 'Africa', 2002, 39.989000000000004, 11926563,
#         672.0386227000001],
#        ['Zimbabwe', 'Africa', 2007, 43.486999999999995, 12311143,
#         469.70929810000007]], dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
country_df=df['country']

# %%
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
type(country_df)
# Out:
# pandas.core.series.Series

# %%
subset=df[['country','continent','year']]

# %%
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.loc[2]
# Out:
# country      Afghanistan
# continent           Asia
# year                1962
# lifeExp           31.997
# pop             10267083
# gdpPercap        853.101
# Name: 2, dtype: object

# %%
df.loc[[2,0]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[1703]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.ix[2]
# Out:
# C:\Users\Sagar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# country      Afghanistan
# continent           Asia
# year                1962
# lifeExp           31.997
# pop             10267083
# gdpPercap        853.101
# Name: 2, dtype: object

# %%
subset=df.loc[:,['year','pop']]

# %%
subset.head()
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460

# %%
df.loc[df['year']==1967,['year','pop']]
# Out:
#       year        pop
# 3     1967   11537966
# 15    1967    1984060
# 27    1967   12760499
# 39    1967    5247469
# 51    1967   22934225
# 63    1967   11872264
# 75    1967    7376998
# 87    1967     202182
# 99    1967   62821884
# 111   1967    9556500
# 123   1967    2427334
# 135   1967    4040665
# 147   1967    3585000
# 159   1967     553541
# 171   1967   88049823
# 183   1967    8310226
# 195   1967    5127935
# 207   1967    3330989
# 219   1967    6960067
# 231   1967    6335506
# 243   1967   20819767
# 255   1967    1733638
# 267   1967    3495967
# 279   1967    8858908
# 291   1967  754550000
# 303   1967   19764027
# 315   1967     217378
# 327   1967   19941073
# 339   1967    1179760
# 351   1967    1588717
# ...    ...        ...
# 1347  1967    2662190
# 1359  1967    1977600
# 1371  1967    4442238
# 1383  1967    1646912
# 1395  1967    3428839
# 1407  1967   20997321
# 1419  1967   32850275
# 1431  1967   11737396
# 1443  1967   12716129
# ...

# %%
df.loc[(df['year']==1967)|(df['pop']>1_000_000),['year','pop']]
# Out:
#       year       pop
# 0     1952   8425333
# 1     1957   9240934
# 2     1962  10267083
# 3     1967  11537966
# 4     1972  13079460
# 5     1977  14880372
# 6     1982  12881816
# 7     1987  13867957
# 8     1992  16317921
# 9     1997  22227415
# 10    2002  25268405
# 11    2007  31889923
# 12    1952   1282697
# 13    1957   1476505
# 14    1962   1728137
# 15    1967   1984060
# 16    1972   2263554
# 17    1977   2509048
# 18    1982   2780097
# 19    1987   3075321
# 20    1992   3326498
# 21    1997   3428038
# 22    2002   3508512
# 23    2007   3600523
# 24    1952   9279525
# 25    1957  10270856
# 26    1962  11000948
# 27    1967  12760499
# 28    1972  14760787
# 29    1977  17152804
# ...    ...       ...
# 1674  1982   9657618
# 1675  1987  11219340
# 1676  1992  13367997
# 1677  1997  15826497
# 1678  2002  18701257
# 1679  2007  22211743
# 1680  1952   2672000
# 1681  1957   3016000
# 1682  1962   3421000
# 1683  1967   3900000
# 1684  1972   4506497
# ...

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df1=LabelEncoder()

# %%
df['country']=df1.fit_transform(df['country'])

# %%
df['country'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: country, dtype: int64

# %%
df.head()
# Out:
#    country continent  year  lifeExp       pop   gdpPercap
# 0        0      Asia  1952   28.801   8425333  779.445314
# 1        0      Asia  1957   30.332   9240934  820.853030
# 2        0      Asia  1962   31.997  10267083  853.100710
# 3        0      Asia  1967   34.020  11537966  836.197138
# 4        0      Asia  1972   36.088  13079460  739.981106

# %%
df['continent'].nunique()
# Out:
# 5

# %%
df2=OneHotEncoder(categorical_features=df['continent'])

# %%
df3=df2.fit_transform(df).to_array()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-78eec0565e01> in <module>()
# ----> 1 df3=df2.fit_transform(df).to_array()
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
#    1811     if isinstance(selected, six.string_types) and selected == "all":
#
# ...

# %%
df.head()
# Out:
#    country continent  year  lifeExp       pop   gdpPercap
# 0        0      Asia  1952   28.801   8425333  779.445314
# 1        0      Asia  1957   30.332   9240934  820.853030
# 2        0      Asia  1962   31.997  10267083  853.100710
# 3        0      Asia  1967   34.020  11537966  836.197138
# 4        0      Asia  1972   36.088  13079460  739.981106

# %%
df3=df[df.continent!='Africa']

# %%
df3
# Out:
#       country continent  year  lifeExp       pop     gdpPercap
# 0           0      Asia  1952   28.801   8425333    779.445314
# 1           0      Asia  1957   30.332   9240934    820.853030
# 2           0      Asia  1962   31.997  10267083    853.100710
# 3           0      Asia  1967   34.020  11537966    836.197138
# 4           0      Asia  1972   36.088  13079460    739.981106
# 5           0      Asia  1977   38.438  14880372    786.113360
# 6           0      Asia  1982   39.854  12881816    978.011439
# 7           0      Asia  1987   40.822  13867957    852.395945
# 8           0      Asia  1992   41.674  16317921    649.341395
# 9           0      Asia  1997   41.763  22227415    635.341351
# 10          0      Asia  2002   42.129  25268405    726.734055
# 11          0      Asia  2007   43.828  31889923    974.580338
# 12          1    Europe  1952   55.230   1282697   1601.056136
# 13          1    Europe  1957   59.280   1476505   1942.284244
# ...

# %%
df2=OneHotEncoder(categorical_features=df['continent'])
df4=df3.fit_transform(df3).to_array()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-2edc43c190af> in <module>()
#       1 df2=OneHotEncoder(categorical_features=df['continent'])
# ----> 2 df4=df2.fit_transform(df3).to_array()
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder(categorical_features= [2])
X = one.fit_transform(one).toarray()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-1f453e61d741> in <module>()
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 one = OneHotEncoder(categorical_features= [2])
# ----> 3 X = one.fit_transform(one).toarray()
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
# ...

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
import numpy as np
df1=df['country']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onc=OneHotEncoder(categorical_features=[df1])

# %%
df=onc.fit_transform(df1).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-e99cc1f34c6c> in <module>()
# ----> 1 df=onc.fit_transform(df1).toarray()
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
#    1811     if isinstance(selected, six.string_types) and selected == "all":
#
# ...
